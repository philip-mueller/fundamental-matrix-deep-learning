# %%
# Change working directory to project root directory as all scripts and imports assume this dir
import os
os.chdir('../')
import sys
sys.path.append('../')

# %%
from dataset_utils.dataset_preparation import prepare_all_fmatrix_silhouette_datasets_from_web, prepare_all_fmatrix_image_datasets_from_web
from dataset_utils.dataset_preparation import prepare_fmatrix_silhouette_dataset_from_web, prepare_fmatrix_image_dataset_from_web
from dataset_utils.dataset_preparation import prepare_synthetic_fmatrix_silhouette_dataset, prepare_all_synthetic_fmatrix_silhouette_datasets
from dataset_utils.dataset_preparation import combine_fmatrix_datasets, split_fmatrix_dataset_all_norms
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
# Silhouette datasets from texture images
prepare_fmatrix_silhouette_dataset_from_web('templeSparseRing')
prepare_fmatrix_silhouette_dataset_from_web('templeRing')
#prepare_all_fmatrix_silhouette_datasets_from_web()
# Out:
# ...
# Preparing silhouette dataset from web: templeSparseRing
# ...
#
# ============================== Dataset download ==============================
# ...
# Done.
# Unpacking zip file...
# Done.
#
# ============================== Silhouette image processing ==============================
# Found the following 16 images for dataset "templeSparseRing":
# ['templeSR0001.png', 'templeSR0002.png', 'templeSR0003.png', 'templeSR0004.png', 'templeSR0005.png', 'templeSR0006.png', 'templeSR0007.png', 'templeSR0008.png', 'templeSR0009.png', 'templeSR0010.png', 'templeSR0011.png', 'templeSR0012.png', 'templeSR0013.png', 'templeSR0014.png', 'templeSR0015.png', 'templeSR0016.png']
# Loading images...
# Done.
# Processing images...
# Done.
# Processed images:
# Only showing first 10 images
# Saving images to dataset "templeSparseRing_silhouette"...
# Done.
# Copying file README.txt
# Copying file templeSR_ang.txt
# Copying file templeSR_par.txt
# Finished processing images.
#
# ...

# %%
# Synthetic horse datasets
prepare_synthetic_fmatrix_silhouette_dataset('horse', 'rotation')
prepare_synthetic_fmatrix_silhouette_dataset('horse', 'rotationZoom')
prepare_synthetic_fmatrix_silhouette_dataset('horse', 'rotationTranslation')
prepare_synthetic_fmatrix_silhouette_dataset('horse', 'rotationTranslationZoom')
prepare_synthetic_fmatrix_silhouette_dataset('horse', 'rotationTranslationFocus')
prepare_synthetic_fmatrix_silhouette_dataset('horse', 'rotationTranslationFocusZoom')
# Out:
# ...
# Preparing synthetic silhouette dataset : synthetic_horse_rotation using 3D mesh file "horse" and camera configuration rotation
# ...
# Using 50 camera parameter combinations
# Reading mesh file "backup/3d_models/horse.ply"
# Rendering dataset synthetic_horse_rotation
# Rendering done.
# Writing parameters to "synthetic_horse_rotation_par.txt"
# Done.
#
# ============================== Fundamental matrix file creation ==============================
# Reading camera dataset file "synthetic_horse_rotation_par.txt" in dataset "synthetic_horse_rotation".
# Combining images and calculating fundamental matrices...
# Done.
# Normalizing fmatrix dataset for norm: None
# FMatrix dataset file "synthetic_horse_rotation_fmatrix.csv" created in dataset "synthetic_horse_rotation".
# Normalizing fmatrix dataset for norm: fro
# FMatrix dataset file "synthetic_horse_rotation_fmatrix_fro.csv" created in dataset "synthetic_horse_rotation".
# Normalizing fmatrix dataset for norm: abs
# ...

# %%
# Synthetic big dodge datasets
prepare_synthetic_fmatrix_silhouette_dataset('big_dodge', 'rotation')
prepare_synthetic_fmatrix_silhouette_dataset('big_dodge', 'rotationZoom')
# Out:
# ...
# Preparing synthetic silhouette dataset : synthetic_big_dodge_rotation using 3D mesh file "big_dodge" and camera configuration rotation
# ...
# Using 50 camera parameter combinations
# Reading mesh file "backup/3d_models/big_dodge.ply"
# Rendering dataset synthetic_big_dodge_rotation
# Rendering done.
# Writing parameters to "synthetic_big_dodge_rotation_par.txt"
# Done.
#
# ============================== Fundamental matrix file creation ==============================
# Reading camera dataset file "synthetic_big_dodge_rotation_par.txt" in dataset "synthetic_big_dodge_rotation".
# Combining images and calculating fundamental matrices...
# Done.
# Normalizing fmatrix dataset for norm: None
# FMatrix dataset file "synthetic_big_dodge_rotation_fmatrix.csv" created in dataset "synthetic_big_dodge_rotation".
# Normalizing fmatrix dataset for norm: fro
# FMatrix dataset file "synthetic_big_dodge_rotation_fmatrix_fro.csv" created in dataset "synthetic_big_dodge_rotation".
# ...

# %%
# Synthetic chopper datasets
prepare_synthetic_fmatrix_silhouette_dataset('chopper', 'rotation')
prepare_synthetic_fmatrix_silhouette_dataset('chopper', 'rotationZoom')
# Out:
# ...
# Preparing synthetic silhouette dataset : synthetic_chopper_rotation using 3D mesh file "chopper" and camera configuration rotation
# ...
# Using 50 camera parameter combinations
# Reading mesh file "backup/3d_models/chopper.ply"
# Rendering dataset synthetic_chopper_rotation
# Rendering done.
# Writing parameters to "synthetic_chopper_rotation_par.txt"
# Done.
#
# ============================== Fundamental matrix file creation ==============================
# Reading camera dataset file "synthetic_chopper_rotation_par.txt" in dataset "synthetic_chopper_rotation".
# Combining images and calculating fundamental matrices...
# Done.
# Normalizing fmatrix dataset for norm: None
# FMatrix dataset file "synthetic_chopper_rotation_fmatrix.csv" created in dataset "synthetic_chopper_rotation".
# Normalizing fmatrix dataset for norm: fro
# FMatrix dataset file "synthetic_chopper_rotation_fmatrix_fro.csv" created in dataset "synthetic_chopper_rotation".
# Normalizing fmatrix dataset for norm: abs
# ...

# %%
# Synthetic street lamp datasets
prepare_synthetic_fmatrix_silhouette_dataset('street_lamp', 'rotation')
prepare_synthetic_fmatrix_silhouette_dataset('street_lamp', 'rotationZoom')
# Out:
# ...
# Preparing synthetic silhouette dataset : synthetic_street_lamp_rotation using 3D mesh file "street_lamp" and camera configuration rotation
# ...
# Using 50 camera parameter combinations
# Reading mesh file "backup/3d_models/street_lamp.ply"
# Rendering dataset synthetic_street_lamp_rotation
# Rendering done.
# Writing parameters to "synthetic_street_lamp_rotation_par.txt"
# Done.
#
# ============================== Fundamental matrix file creation ==============================
# Reading camera dataset file "synthetic_street_lamp_rotation_par.txt" in dataset "synthetic_street_lamp_rotation".
# Combining images and calculating fundamental matrices...
# Done.
# Normalizing fmatrix dataset for norm: None
# FMatrix dataset file "synthetic_street_lamp_rotation_fmatrix.csv" created in dataset "synthetic_street_lamp_rotation".
# Normalizing fmatrix dataset for norm: fro
# FMatrix dataset file "synthetic_street_lamp_rotation_fmatrix_fro.csv" created in dataset "synthetic_street_lamp_rotation".
# ...

# %%
# Synthetic galleon datasets
prepare_synthetic_fmatrix_silhouette_dataset('galleon', 'rotation')
prepare_synthetic_fmatrix_silhouette_dataset('galleon', 'rotationZoom')
# Out:
# ...
# Preparing synthetic silhouette dataset : synthetic_galleon_rotation using 3D mesh file "galleon" and camera configuration rotation
# ...
# Using 50 camera parameter combinations
# Reading mesh file "backup/3d_models/galleon.ply"
# Rendering dataset synthetic_galleon_rotation
# Rendering done.
# Writing parameters to "synthetic_galleon_rotation_par.txt"
# Done.
#
# ============================== Fundamental matrix file creation ==============================
# Reading camera dataset file "synthetic_galleon_rotation_par.txt" in dataset "synthetic_galleon_rotation".
# Combining images and calculating fundamental matrices...
# Done.
# Normalizing fmatrix dataset for norm: None
# FMatrix dataset file "synthetic_galleon_rotation_fmatrix.csv" created in dataset "synthetic_galleon_rotation".
# Normalizing fmatrix dataset for norm: fro
# FMatrix dataset file "synthetic_galleon_rotation_fmatrix_fro.csv" created in dataset "synthetic_galleon_rotation".
# Normalizing fmatrix dataset for norm: abs
# ...

# %%
# Synthetic dolphins datasets
prepare_synthetic_fmatrix_silhouette_dataset('dolphins', 'rotation')
prepare_synthetic_fmatrix_silhouette_dataset('dolphins', 'rotationZoom')
# Out:
# ...
# Preparing synthetic silhouette dataset : synthetic_dolphins_rotation using 3D mesh file "dolphins" and camera configuration rotation
# ...
# Using 50 camera parameter combinations
# Reading mesh file "backup/3d_models/dolphins.ply"
# Rendering dataset synthetic_dolphins_rotation
# Rendering done.
# Writing parameters to "synthetic_dolphins_rotation_par.txt"
# Done.
#
# ============================== Fundamental matrix file creation ==============================
# Reading camera dataset file "synthetic_dolphins_rotation_par.txt" in dataset "synthetic_dolphins_rotation".
# Combining images and calculating fundamental matrices...
# Done.
# Normalizing fmatrix dataset for norm: None
# FMatrix dataset file "synthetic_dolphins_rotation_fmatrix.csv" created in dataset "synthetic_dolphins_rotation".
# Normalizing fmatrix dataset for norm: fro
# FMatrix dataset file "synthetic_dolphins_rotation_fmatrix_fro.csv" created in dataset "synthetic_dolphins_rotation".
# ...

# %%
# Synthetic stratocaster datasets
prepare_synthetic_fmatrix_silhouette_dataset('stratocaster', 'rotation')
# Out:
# ...
# Preparing synthetic silhouette dataset : synthetic_stratocaster_rotation using 3D mesh file "stratocaster" and camera configuration rotation
# ...
# Using 50 camera parameter combinations
# Reading mesh file "backup/3d_models/stratocaster.ply"
# Rendering dataset synthetic_stratocaster_rotation
# Rendering done.
# Writing parameters to "synthetic_stratocaster_rotation_par.txt"
# camer parameter file "datasets/synthetic_stratocaster_rotation/synthetic_stratocaster_rotation_par.txt" already exists. Skipping creation
# Done.
#
# ============================== Fundamental matrix file creation ==============================
# All fmatrix files "['synthetic_stratocaster_rotation_fmatrix.csv', 'synthetic_stratocaster_rotation_fmatrix_fro.csv', 'synthetic_stratocaster_rotation_fmatrix_abs.csv']" already exist. Skipping creation
#
# ==================== Dataset splitting (TRAIN, VAL, TEST) ====================
# ...

# %%
# All synthetic datasets
#prepare_all_synthetic_fmatrix_silhouette_datasets()

# %%
# Combined/mixed rotation datasets
combine_fmatrix_datasets(['synthetic_horse_rotation', 
                          'synthetic_big_dodge_rotation',
                          'synthetic_chopper_rotation',
                          'synthetic_street_lamp_rotation',
                          'synthetic_galleon_rotation',
                          'synthetic_dolphins_rotation'], 'combined_rotation')
split_fmatrix_dataset_all_norms('combined_rotation')
# Out:
# ============================== Combining datasets==============================
# The following datasets are combined:
# ['synthetic_horse_rotation', 'synthetic_big_dodge_rotation', 'synthetic_chopper_rotation', 'synthetic_street_lamp_rotation', 'synthetic_galleon_rotation', 'synthetic_dolphins_rotation']
# Copying images...
# Combining datasets for norm None...
# Combined 14700 samples
# Writing to file "combined_rotation_fmatrix.csv"
# Done.
# Combining datasets for norm fro...
# Combined 14700 samples
# Writing to file "combined_rotation_fmatrix_fro.csv"
# Done.
# Combining datasets for norm abs...
# Combined 14700 samples
# Writing to file "combined_rotation_fmatrix_abs.csv"
# Done.
#
# ==================== Dataset splitting (TRAIN, VAL, TEST) ====================
# Splitting dataset "combined_rotation" (file: "combined_rotation_fmatrix.csv") with ratio (TRAIN: 0.800000, VAL: 0.100000, TEST: 0.100000)
# FULL size: 14700
# TRAIN size: 11760
# VAL size: 1470
# TEST size: 1470
# ...

# %%
# Combined/mixed rotation and zoom datasets
combine_fmatrix_datasets(['synthetic_horse_rotationZoom', 
                          'synthetic_big_dodge_rotationZoom',
                          'synthetic_chopper_rotationZoom',
                          'synthetic_street_lamp_rotationZoom',
                          'synthetic_galleon_rotationZoom',
                          'synthetic_dolphins_rotationZoom'], 'combined_rotationZoom')
split_fmatrix_dataset_all_norms('combined_rotationZoom')
# Out:
# ============================== Combining datasets==============================
# The following datasets are combined:
# ['synthetic_horse_rotationZoom', 'synthetic_big_dodge_rotationZoom', 'synthetic_chopper_rotationZoom', 'synthetic_street_lamp_rotationZoom', 'synthetic_galleon_rotationZoom', 'synthetic_dolphins_rotationZoom']
# Copying images...
# Combining datasets for norm None...
# Combined 134100 samples
# Writing to file "combined_rotationZoom_fmatrix.csv"
# Done.
# Combining datasets for norm fro...
# Combined 134100 samples
# Writing to file "combined_rotationZoom_fmatrix_fro.csv"
# Done.
# Combining datasets for norm abs...
# Combined 134100 samples
# Writing to file "combined_rotationZoom_fmatrix_abs.csv"
# Done.
#
# ==================== Dataset splitting (TRAIN, VAL, TEST) ====================
# Splitting dataset "combined_rotationZoom" (file: "combined_rotationZoom_fmatrix.csv") with ratio (TRAIN: 0.800000, VAL: 0.100000, TEST: 0.100000)
# FULL size: 134100
# ...
